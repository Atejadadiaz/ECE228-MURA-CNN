# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# DataFrames
epochs = list(range(1, 11))

resnet18 = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'ResNet-18',
    'Train Acc': [0.6948, 0.7378, 0.7552, 0.7676, 0.7765, 0.8043, 0.8106, 0.8175, 0.8214, 0.8228],
    'Val Acc': [0.6919, 0.7194, 0.7338, 0.7516, 0.7441, 0.7782, 0.7876, 0.7857, 0.7932, 0.7895],
    'Kappa': [0.3788, 0.4277, 0.4626, 0.4955, 0.4794, 0.5517, 0.5720, 0.5677, 0.5828, 0.5765]
})

resnet50 = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'ResNet-50',
    'Train Acc': [0.7107, 0.7524, 0.7689, 0.7746, 0.7800, 0.8084, 0.8177, 0.8230, 0.8281, 0.8301],
    'Val Acc': [0.7179, 0.7007, 0.6988, 0.7488, 0.7535, 0.7979, 0.7992, 0.7964, 0.7939, 0.8014],
    'Kappa': [0.4279, 0.3868, 0.4019, 0.4906, 0.5055, 0.5915, 0.5943, 0.5882, 0.5831, 0.5985]
})

densenet = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'DenseNet-121',
    'Train Acc': [0.7073, 0.7410, 0.7608, 0.7711, 0.7796, 0.8090, 0.8176, 0.8216, 0.8237, 0.8265],
    'Val Acc': [0.6975, 0.7175, 0.7348, 0.7110, 0.7501, 0.7945, 0.7926, 0.7951, 0.7995, 0.8036],
    'Kappa': [0.3820, 0.4233, 0.4644, 0.4080, 0.4925, 0.5861, 0.5806, 0.5856, 0.5954, 0.6036]
})

resnet18_no_aug = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'ResNet-18 (no aug)',
    'Train Acc': [0.5894, 0.6118, 0.6315, 0.6440, 0.6646, 0.7012, 0.7163, 0.7254, 0.7344, 0.7409],
    'Val Acc': [0.5518, 0.5721, 0.5374, 0.5965, 0.5518, 0.6444, 0.6703, 0.6841, 0.6841, 0.6838],
    'Val Loss': [0.6885, 0.7042, 0.7172, 0.7009, 0.8547, 0.6573, 0.6175, 0.6026, 0.5978, 0.5990],
    'Kappa': [None]*10
})

resnet50_no_aug = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'ResNet-50 (no aug)',
    'Train Acc': [0.5945, 0.5914, 0.5939, 0.5942, 0.5991, 0.6252, 0.6484, 0.6704, 0.6897, 0.7038],
    'Val Acc': [0.5214, 0.5214, 0.5217, 0.5214, 0.5508, 0.6121, 0.6156, 0.6550, 0.6537, 0.6894],
    'Val Loss': [0.7186, 0.6932, 0.6920, 1.4172, 0.6770, 0.6488, 0.6498, 0.6116, 0.6141, 0.5879],
    'Kappa': [0.0000, 0.0000, 0.0007, 0.0000, 0.0767, 0.2236, 0.2081, 0.2950, 0.2920, 0.3667]
})

densenet_no_aug = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'DenseNet-121 (no aug)',
    'Train Acc': [0.5902, 0.6037, 0.6011, 0.5993, 0.6025, 0.6192, 0.6399, 0.6579, 0.6859, 0.7019],
    'Val Acc': [0.5217, 0.5186, 0.5211, 0.5199, 0.5546, 0.5881, 0.5959, 0.6309, 0.6134, 0.6625],
    'Val Loss': [0.7177, 0.7036, 0.7114, 0.7237, 0.6851, 0.6726, 0.6657, 0.6450, 0.6738, 0.6011],
    'Kappa': [None]*10
})

convnex = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'ConvNeXt - lr = 1e-2',
    'Train Acc': [0.5955, 0.5958, 0.5958, 0.5957, 0.5959, 0.5959, 0.5959, 0.5959, 0.5959, 0.5959],
    'Val Acc': [0.5214] * 10,
    'Val Loss': [0.7117, 0.7023, 0.6959, 0.6987, 0.7011, 0.7038, 0.7038, 0.7030, 0.7037, 0.7040],
    'Kappa': [0.0] * 10
})

convnex2 = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'ConvNeXt - lr = 1e-4',
    'Train Acc': [0.7824, 0.8225, 0.8397, 0.8560, 0.8702, 0.9086, 0.9181, 0.9265, 0.9335, 0.9384],
    'Val Acc': [0.8008, 0.8236, 0.8226, 0.8327, 0.8280, 0.8342, 0.8355, 0.8370, 0.8361, 0.8352],
    'Val Loss': [0.4530, 0.4197, 0.4075, 0.4135, 0.4436, 0.4717, 0.4858, 0.4916, 0.5189, 0.5329],
    'Kappa': [0.5953, 0.6436, 0.6430, 0.6619, 0.6543, 0.6663, 0.6685, 0.6720, 0.6702, 0.6685]
})

resnet50_lr = pd.DataFrame({
    'Epoch': epochs,
    'Model': 'ResNet-50 lr = 1e-4',
    'Train Acc': [0.7869, 0.8202, 0.8359, 0.8472, 0.8619, 0.8994, 0.9183, 0.9300, 0.9384, 0.9474],
    'Val Acc': [0.8070, 0.8164, 0.7923, 0.8164, 0.8220, 0.8292, 0.8255, 0.8236, 0.8317, 0.8280],
    'Val Loss': [0.4448, 0.4297, 0.4943, 0.4492, 0.4277, 0.4550, 0.5048, 0.5336, 0.5684, 0.6162],
    'Kappa': [0.6102, 0.6295, 0.5787, 0.6285, 0.6417, 0.6561, 0.6482, 0.6455, 0.6619, 0.6540]
})

df_all_metrics = pd.concat([
    resnet18, resnet50, densenet,
    resnet18_no_aug, resnet50_no_aug, densenet_no_aug, convnex, convnex2, resnet50_lr
], ignore_index=True)

# Train Accuracy
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_all_metrics, x='Epoch', y='Train Acc', hue='Model', marker='o')
plt.title('Training Accuracy per Epoch')
plt.ylabel('Train Accuracy')
plt.ylim(0.5, 1)
plt.xticks(range(1, 11))
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig("train_accuracy_comparison.png")
plt.show()

# Validation Accuracy
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_all_metrics, x='Epoch', y='Val Acc', hue='Model', marker='o')
plt.title('Validation Accuracy per Epoch')
plt.ylabel('Val Accuracy')
plt.ylim(0.5, 0.9)
plt.xticks(range(1, 11))
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig("val_accuracy_comparison.png")
plt.show()

# Kappa Score
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_all_metrics.dropna(subset=['Kappa']), x='Epoch', y='Kappa', hue='Model', marker='o')
plt.title("Cohen's Kappa Score per Epoch")
plt.ylabel("Kappa Score")
plt.ylim(0.0, 0.75)
plt.xticks(range(1, 11))
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig("kappa_score_comparison.png")
plt.show()
# Out:
# <ipython-input-1-18a662c1e182>:86: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_metrics = pd.concat([
